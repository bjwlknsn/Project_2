# %%
import pandas as pd

# %%
data_file = "Resources/mountains_db.csv"

# %%
mountains_data_df = pd.read_csv(data_file)
mountains_data_df.to_html('mountains_data_html.html', index=False)

# %%
mountains_data_df
# Out:
#                          _id  ID          Mountain Peak  \
# 0   608215be210482538e418ea1   1             Mt. Elbert
# 1   608215be210482538e418ea2   2            Mt. Massive
# 2   608215be210482538e418ea3   3            Mt. Harvard
# 3   608215be210482538e418ea4   4            Blanca Peak
# 4   608215be210482538e418ea5   5          La Plata Peak
# 5   608215be210482538e418ea6   6       Uncompahgre Peak
# 6   608215be210482538e418ea7   7          Crestone Peak
# 7   608215be210482538e418ea8   8            Mt. Lincoln
# 8   608215be210482538e418ea9   9            Castle Peak
# 9   608215be210482538e418eaa  10             Grays Peak
# 10  608215be210482538e418eab  11             Mt. Antero
# 11  608215be210482538e418eac  12           Torreys Peak
# 12  608215be210482538e418ead  13          Quandary Peak
# 13  608215be210482538e418eae  14              Mt. Evans
# 14  608215be210482538e418eaf  15             Longs Peak
# 15  608215be210482538e418eb0  16             Mt. Wilson
# ...
