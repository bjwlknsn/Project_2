# %%
import pandas as pd

# %%
data_file = "Resources/cleaned_breweries.csv"

# %%
breweries_data_df = pd.read_csv(data_file)
breweries_data_df.to_html('breweries_data_html.html', index=False)

# %%
breweries_data_df
# Out:
#                                   Brewery  \
# 0                         Equinox Brewing
# 1          Pug Ryan's Steak House Brewery
# 2    Blue Moon Brewing Co. at the Sandlot
# 3                   Odell Brewing Company
# 4                    Vail Brewing Company
# ..                                    ...
# 232                      300 Suns Brewing
# 233             Finkel & Garf Brewing Co.
# 234                     Pumphouse Brewery
# 235         BJ's Restaurant and Brewhouse
# 236                       Mockery Brewing
#
#                                               Address  \
# 0        133 Remington Street, Fort Collins, CO 80524
# 1                   104 Village Pl., Dillon, CO 80435
# 2                 2161 Blake Street, Denver, CO 80205
# 3          800 E. Lincoln Ave, Fort Collins, CO 80524
# 4            41290 B-2 & B-3 US HWY 6, Vail, CO 81657
# ..                                                ...
# 232                  335 1st Ave., Longmont, CO 80501
# ...
