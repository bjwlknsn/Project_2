# %%
import pandas as pd

# %%
data_file = "Resources/camping_14ers.csv"

# %%
camping_data_df = pd.read_csv(data_file)
camping_data_df.to_html('camping_data_html.html', index=False)

# %%
camping_data_df
# Out:
#       Unnamed: 0 Mountain Peak  Distance from Campsite (miles)  \
# 0              0    Mt. Elbert                       11.667981
# 1              1    Mt. Elbert                       11.652809
# 2              2    Mt. Elbert                       16.725207
# 3              3    Mt. Elbert                        6.697035
# 4              4    Mt. Elbert                       17.685043
# ...          ...           ...                             ...
# 1098        1098  Culebra Peak                       14.263277
# 1099        1099  Culebra Peak                       14.263277
# 1100        1100  Culebra Peak                       13.418729
# 1101        1101  Culebra Peak                        9.621643
# 1102        1102  Culebra Peak                        9.941611
#
#                     name     Long     Lat  Peak Longitude  Peak Latitude
# 0               Baby Doe -106.351  39.270       -106.4454        39.1178
# ...
