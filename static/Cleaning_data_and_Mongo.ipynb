# %%
# Import Dependencies
import os
import pandas as pd
import numpy as np
from math import sin, cos, sqrt, atan2, radians
import json
import pymongo

# %%
with open("../Resources/chargerStations.js") as f:
    charger_json = json.load(f)
with open("../Resources/gasStations.js") as f:
    gas_json = json.load(f)
display(charger_json.keys())
display(gas_json.keys())

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)


db = client.FullData
# Out:
# dict_keys(['type', 'name', 'crs', 'features'])
# dict_keys(['type', 'name', 'crs', 'features'])

# %%
#Gas Stations data paired down and listified
gas_names = []
gas_longs = []
gas_lats = []
for x in range(0,len(gas_json["features"])):
    gas_names.append(gas_json["features"][x]["properties"]["name"])
    gas_longs.append(gas_json["features"][x]["geometry"]["coordinates"][0])
    gas_lats.append(gas_json["features"][x]["geometry"]["coordinates"][1])
    
# Charger Stations data paired down and listified  
charger_names = []
charger_longs = []
charger_lats = []
for x in range(0, len(charger_json["features"])):
    charger_names.append(charger_json["features"][x]["properties"]["name"])
    charger_longs.append(charger_json["features"][x]["geometry"]["coordinates"][0])
    charger_lats.append(charger_json["features"][x]["geometry"]["coordinates"][1])

# %%
# Create DataFrames
charger_df = pd.DataFrame({
    "Charger Station Name" : charger_names,
    "Charger Station Longitude" : charger_longs,
    "Charger Station Latitude" : charger_lats
})
gas_df = pd.DataFrame({
    "Gas Station Name" : gas_names,
    "Gas Station Longitude" : gas_longs,
    "Gas Station Latitude" : gas_lats
})

# %%
#Bring in campsites and mountains csv
campsites = pd.read_csv("../Resources/southwest_camp_data.csv", encoding = "utf-8")
campsites = campsites[["Long", "Lat", "name", "type", "dates", "# sites", "Elevation", "State"]]
co_campsites = campsites[campsites["State"] == "CO"]
display(co_campsites.head())

mountains = pd.read_csv("../Resources/14ers_data.csv", encoding = "ISO-8859–1")
display(mountains.head())

mountains_db = db.mountains_db
data = mountains.to_dict(orient = "records")
mountains_db.insert_many(data)
# Out:
#         Long     Lat              name type              dates # sites  \
# 259 -106.345  37.379           Alamosa   NF                         10
# 260 -106.858  38.654            Almont   NF    mid may-mid sep      10
# 261 -105.562  38.080          Alvarado   NF  early jun-mid oct      50
# 262 -107.665  38.019      Amphitheater   NF   mid jun-late sep      35
# 263 -106.221  38.583  Angel of Shavano   NF                         20
#
#     Elevation State
# 259      8665    CO
# 260      8018    CO
# 261      8986    CO
# 262      8320    CO
# 263      9180    CO
#    ID  Mountain Peak          Mountain Range  Elevation_ft fourteener  \
# 0   1     Mt. Elbert           Sawatch Range         14440          Y
# 1   2    Mt. Massive           Sawatch Range         14428          Y
# 2   3    Mt. Harvard           Sawatch Range         14421          Y
# 3   4    Blanca Peak  Sangre de Cristo Range         14351          Y
# 4   5  La Plata Peak           Sawatch Range         14343          Y
#
#    Prominence_ft  Isolation_mi  Peak Longitude  Peak Latitude  \
# 0           9093        670.00       -106.4454        39.1178
# 1           1961          5.06       -106.4757        39.1875
# 2           2360         14.93       -106.3207        38.9244
# 3           5326        103.40       -105.4856        37.5775
# 4           1836          6.28       -106.4729        39.0294
#
#      Standard Route  Standard Route Distance (miles)  Elevation Gain_ft  \
# 0  Northeast Ridge                              9.50               4700
# 1      East Slopes                             14.50               4500
# 2     South Slopes                             14.00               4600
# 3  Northwest Ridge                             17.00               6500
# 4  Northwest Ridge                              9.25               4500
#
#      Difficulty  Traffic Low  Traffic High  \
# 0       Class 1        20000         25000
# 1       Class 2         7000         10000
# 2       Class 2         5000          7000
# 3  Hard Class 2         1000          3000
# 4       Class 2         5000          7000
#
#                                                photo
# 0  https://www.14ers.com/photos/mtelbert/peakphot...
# 1  https://www.14ers.com/photos/mtmassive/peakpho...
# 2  https://www.14ers.com/photos/harvardgroup/peak...
# 3  https://www.14ers.com/photos/blancagroup/peakp...
# 4  https://www.14ers.com/photos/laplatapeak/peakp...

# %%
# Create empty list to append information
distance_list = []
mountain_list = []
camp_list = []
co_campsites_lats = []
co_campsites_longs = []

#iterate through mountains and co_example append results to empty list. use math to find radius of 20 miles
for l,m,n in zip(mountains["Mountain Peak"],mountains["Peak Latitude"],mountains["Peak Longitude"]):
    lat1 = radians(m)
    lon1 = radians(n)
    for i, j, k in zip(co_campsites["Lat"],co_campsites["Long"], co_campsites["name"], ):
        lat2 = radians(i)
        lon2 = radians(j)
        camp_name = k
        R = 3958.8
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        distance = (R * c)
        if distance <= 20:
            mountain_list.append(l)
            distance_list.append(distance)
            camp_list.append(camp_name)
            co_campsites_lats.append(i)
            co_campsites_longs.append(j)

# %%
# Create Pandas DF and utilizing the lists above. Drop any duplicates from the new DF
distance_df = pd.DataFrame({
    "Mountain Peak": mountain_list,
    "Distance from Campsite (mi)" : distance_list,
    "name": camp_list,
    "Campsite Latitude" : co_campsites_lats,
    "Campsite Longitude" : co_campsites_longs})
distance_df = distance_df.drop_duplicates()
display(distance_df.head())

everything_14ers = db.everything_14ers_db
data = distance_df.to_dict(orient = "records")
everything_14ers.insert_many(data)
# Out:
#   Mountain Peak  Distance from Campsite (mi)               name  \
# 0    Mt. Elbert                    11.667981           Baby Doe
# 1    Mt. Elbert                    11.652809  Belle of Colorado
# 2    Mt. Elbert                    16.725207            Chapman
# 3    Mt. Elbert                     6.697035             Dexter
# 4    Mt. Elbert                    17.685043          Difficult
#
#    Campsite Latitude  Campsite Longitude
# 0             39.270            -106.351
# 1             39.269            -106.349
# 2             39.309            -106.637
# 3             39.092            -106.325
# 4             39.141            -106.774

# %%
camp_merge = pd.merge(distance_df, co_campsites, on = "name")
mountains_merge = pd.merge(camp_merge, mountains, on = "Mountain Peak")
cleaned_mountains = mountains_merge[["Mountain Peak", "Distance from Campsite (mi)", "name","Long", "Lat", "dates", "# sites", "Isolation_mi", "Peak Longitude", "Peak Latitude"]]
cleaned_mountains = cleaned_mountains.rename(columns = {"name" : "Campsite Name", "Long": "Campsite Longitude", "Lat": "Campsite Latitude", "dates" : "Dates", "# sites" : "#_Sites"})
display(cleaned_mountains.head())
# Out:
#   Mountain Peak  Distance from Campsite (mi)      Campsite Name  \
# 0    Mt. Elbert                    11.667981           Baby Doe
# 1    Mt. Elbert                    11.652809  Belle of Colorado
# 2    Mt. Elbert                    16.725207            Chapman
# 3    Mt. Elbert                     6.697035             Dexter
# 4    Mt. Elbert                    17.685043          Difficult
#
#    Campsite Longitude  Campsite Latitude               Dates #_Sites  \
# 0            -106.351             39.270  early jun-late aug      50
# 1            -106.349             39.269                          19
# 2            -106.637             39.309     mid may-mid sep      84
# 3            -106.325             39.092                          24
# 4            -106.774             39.141     mid may-mid sep      47
#
#    Isolation_mi  Peak Longitude  Peak Latitude
# 0         670.0       -106.4454        39.1178
# 1         670.0       -106.4454        39.1178
# 2         670.0       -106.4454        39.1178
# 3         670.0       -106.4454        39.1178
# 4         670.0       -106.4454        39.1178

# %% [markdown]
# Find Distances from Various Points

# %%
charger_distance_list = []
mountain_charger_list = []
charger_lats1 = []
charger_longs1 = []
charger_names1 = []
for l,m,n in zip(mountains["Mountain Peak"],mountains["Peak Latitude"],mountains["Peak Longitude"]):
    lat1 = radians(m)
    lon1 = radians(n)
    for i, j, k in zip(charger_df["Charger Station Latitude"], charger_df["Charger Station Longitude"], charger_df["Charger Station Name"]):
        lat2 = radians(i)
        lon2 = radians(j)
        Name = k
        R = 3958.8
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        distance = (R * c)
        if distance <= 20:
            mountain_charger_list.append(l)
            charger_distance_list.append(distance)
            charger_lats1.append(i)
            charger_longs1.append(j)
            charger_names1.append(Name)

# %%
charger_mountain_df = pd.DataFrame({
    "Charger Station Name": charger_names1,
    "Mountain Peak": mountain_charger_list,
    "Charging Distance from Mountain Peak (mi)" : charger_distance_list,
    "Charging Station Latitude": charger_lats1,
    "Charging Station Longitude" : charger_longs1,
})
display(charger_mountain_df.head())

everything_14ers = db.everything_14ers_db
data = charger_mountain_df.to_dict(orient = "records")
everything_14ers.insert_many(data)
# Out:
#         Charger Station Name Mountain Peak  \
# 0                       None   Mt. Massive
# 1                  BV Charge   Mt. Harvard
# 2  South Main Public Parking   Mt. Harvard
# 3            Riverfront Park   Mt. Harvard
# 4         Tesla Supercharger   Mt. Lincoln
#
#    Charging Distance from Mountain Peak (mi)  Charging Station Latitude  \
# 0                                  18.320254                  39.191468
# 1                                  11.705837                  38.841832
# 2                                  12.207821                  38.841441
# 3                                  11.930070                  38.846897
# 4                                  19.462486                  39.631412
#
#    Charging Station Longitude
# 0                 -106.817763
# 1                 -106.130655
# 2                 -106.120300
# 3                 -106.122483
# 4                 -106.070762

# %%
gas_distance_list = []
mountain_gas_list = []
gas_lats1 = []
gas_longs1 = []
gas_names1 = []
for l,m,n in zip(mountains["Mountain Peak"],mountains["Peak Latitude"],mountains["Peak Longitude"]):
    lat1 = radians(m)
    lon1 = radians(n)
    for i, j, k in zip(gas_df["Gas Station Latitude"], gas_df["Gas Station Longitude"], gas_df["Gas Station Name"]):
        lat2 = radians(i)
        lon2 = radians(j)
        Name = k
        R = 3958.8
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        distance = (R * c)
        if distance <= 20:
            mountain_gas_list.append(l)
            gas_distance_list.append(distance)
            gas_lats1.append(i)
            gas_longs1.append(j)
            gas_names1.append(Name)

# %%
gas_mountain_df = pd.DataFrame({
    "Gas Station Name": gas_names1,
    "Mountain Peak": mountain_gas_list,
    "Gas Station Distance from Mountain Peak (mi)" : gas_distance_list,
    "Gas Station Latitude": gas_lats1,
    "Gas Station Longitude" : gas_longs1,
})
display(gas_mountain_df.head())

everything_14ers = db.everything_14ers_db
data = gas_mountain_df.to_dict(orient = "records")
everything_14ers.insert_many(data)
# Out:
#    Gas Station Name Mountain Peak  \
# 0             Shell    Mt. Elbert
# 1  Diamond Shamrock    Mt. Elbert
# 2          Kum & Go    Mt. Elbert
# 3       Phillips 66    Mt. Elbert
# 4            Conoco    Mt. Elbert
#
#    Gas Station Distance from Mountain Peak (mi)  Gas Station Latitude  \
# 0                                      8.980248             39.223783
# 1                                     12.090677             39.244833
# 2                                     12.145856             39.246371
# 3                                     12.834498             39.260375
# 4                                     12.850290             39.260834
#
#    Gas Station Longitude
# 0            -106.348358
# 1            -106.290142
# 2            -106.290747
# 3            -106.291778
# 4            -106.292028

# %%
breweries_df = pd.read_csv("../Resources/cleaned_breweries.csv", encoding = "utf-8")
display(breweries_df.head())
# Out:
#                                 Brewery  \
# 0                       Equinox Brewing
# 1        Pug Ryan's Steak House Brewery
# 2  Blue Moon Brewing Co. at the Sandlot
# 3                 Odell Brewing Company
# 4                  Vail Brewing Company
#
#                                         Address  \
# 0  133 Remington Street, Fort Collins, CO 80524
# 1             104 Village Pl., Dillon, CO 80435
# 2           2161 Blake Street, Denver, CO 80205
# 3    800 E. Lincoln Ave, Fort Collins, CO 80524
# 4      41290 B-2 & B-3 US HWY 6, Vail, CO 81657
#
#                          Website  Latitudes  Longitudes
# 0  http://www.equinoxbrewing.com  40.586343 -105.075875
# 1       https://www.pugryans.com  39.628010 -106.046430
# 2     http://millercoorsblog.com  39.755701 -104.992736
# 3   http://www.odellbrewing.com/  40.589475 -105.063322
# 4       http://vailbrewingco.com  39.620575 -106.469623

# %%
beer_distance_list = []
mountain_beer_list = []
beer_lats = []
beer_longs = []
beer_names = []
beer_addresses = []
beer_websites = []
for l,m,n in zip(mountains["Mountain Peak"],mountains["Peak Latitude"],mountains["Peak Longitude"]):
    lat1 = radians(m)
    lon1 = radians(n)
    for i, j, k, o,p in zip(breweries_df["Latitudes"], breweries_df["Longitudes"], breweries_df["Brewery"], breweries_df["Address"], breweries_df["Website"]):
        lat2 = radians(i)
        lon2 = radians(j)
        Name = k
        R = 3958.8
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        distance = (R * c)
        if distance <= 20:
            mountain_beer_list.append(l)
            beer_distance_list.append(distance)
            beer_lats.append(i)
            beer_longs.append(j)
            beer_names.append(Name)
            beer_addresses.append(o)
            beer_websites.append(p)

# %%
brewery_mountain_df = pd.DataFrame({
    "Brewery Name" : beer_names,
    "Brewery Address" : beer_addresses,
    "Brewery Website" : beer_websites,
    "Mountain Peak" : mountain_beer_list,
    "Brewery Distance From Mountain Peak (mi)" : beer_distance_list,
    "Brewery Longitudes" : beer_longs,
    "Brewery Latitudes" : beer_lats,
})
display(brewery_mountain_df.head())

everything_14ers = db.everything_14ers_db
data = brewery_mountain_df.to_dict(orient = "records")
everything_14ers.insert_many(data)
# Out:
#                  Brewery Name                        Brewery Address  \
# 0         Two Mile Brewing Co  101 Harrison Ave, Leadville, CO 80461
# 1       Aspen Brewing Company     304 E Hopkins Ave, Aspen, CO 81611
# 2         Two Mile Brewing Co  101 Harrison Ave, Leadville, CO 80461
# 3         Two Mile Brewing Co  101 Harrison Ave, Leadville, CO 80461
# 4  Colorado Boy Pub & Brewery     602 Clinton St., Ridgway, CO 81432
#
#                        Brewery Website     Mountain Peak  \
# 0           https://twomilebrewing.com        Mt. Elbert
# 1      http://aspenbrewingcompany.com/       Mt. Massive
# 2           https://twomilebrewing.com       Mt. Massive
# 3           https://twomilebrewing.com     La Plata Peak
# 4  https://www.coloradoboy.com/ridgway  Uncompahgre Peak
#
#    Brewery Distance From Mountain Peak (mi)  Brewery Longitudes  \
# 0                                 12.059106         -106.290761
# 1                                 18.455272         -106.820301
# 2                                 10.658761         -106.290761
# 3                                 17.790090         -106.290761
# 4                                 17.013095         -107.757814
#
#    Brewery Latitudes
# 0          39.244657
# 1          39.190323
# 2          39.244657
# 3          39.244657
# 4          38.152289

# %%
hot_springs = pd.read_csv("../Resources/hot_Springs1.csv", encoding = "utf-8")
hot_springs = hot_springs[["0", "1", "2", "3"]]
hot_springs = hot_springs.rename(columns = ({
    "0" : "Hot Spring Name",
    "1" : "Town", 
    "2" : "Hot Spring Latitude", 
    "3" : "Hot Spring Longitude"}))
display(hot_springs.head())
# Out:
#                         Hot Spring Name               Town  \
# 0           Strawberry Park Hot Springs  Steamboat Springs
# 1            The Springs Resort and Spa     Pagosa Springs
# 2             Waunita Hot Springs Ranch           Gunnison
# 3           Glenwood Hot Springs Resort   Glenwood Springs
# 4  Avalanche Ranch Cabins & Hot Springs           Redstone
#
#    Hot Spring Latitude  Hot Spring Longitude
# 0            40.559761           -106.849431
# 1            37.264588           -107.010919
# 2            38.515375           -106.508695
# 3            39.550377           -107.322922
# 4            39.247890           -107.237298

# %%
hs_distance_list = []
mountain_hs_list = []
hs_lats = []
hs_longs = []
hs_names = []
hs_towns = []
for l,m,n in zip(mountains["Mountain Peak"],mountains["Peak Latitude"],mountains["Peak Longitude"]):
    lat1 = radians(m)
    lon1 = radians(n)
    for i, j, k, o in zip(hot_springs["Hot Spring Latitude"], hot_springs["Hot Spring Longitude"], hot_springs["Hot Spring Name"], hot_springs["Town"]):
        lat2 = radians(i)
        lon2 = radians(j)
        Name = k
        R = 3958.8
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        distance = (R * c)
        if distance <= 20:
            mountain_hs_list.append(l)
            hs_distance_list.append(distance)
            hs_lats.append(i)
            hs_longs.append(j)
            hs_names.append(Name)
            hs_towns.append(o)

# %%
hs_mountain_df = pd.DataFrame({
    "Hot Spring Name" : hs_names,
    "Town" : hs_towns,
    "Mountain Peak" : mountain_hs_list,
    "HS Distance From Mountain Peak (mi)" : hs_distance_list,
    "Hot Spring Longitudes" : hs_longs,
    "Hot Spring Latitudes" : hs_lats,
})
display(hs_mountain_df.head())

everything_14ers = db.everything_14ers_db
data = hs_mountain_df.to_dict(orient = "records")
everything_14ers.insert_many(data)
# Out:
#                       Hot Spring Name         Town Mountain Peak  \
# 0  Mount Princeton Hot Springs Resort      Nathrop   Mt. Harvard
# 1             Aqua Hot Spring & Cabin  Buena Vista   Mt. Harvard
# 2           Antero Hot Springs Cabins      Nathrop   Mt. Harvard
# 3    Cottonwood Hot Springs Inn & Spa  Buena Vista   Mt. Harvard
# 4      Great Sand Dunes Swimming Pool      Alamosa   Blanca Peak
#
#    HS Distance From Mountain Peak (mi)  Hot Spring Longitudes  \
# 0                            15.748262            -106.162633
# 1                            15.948175            -106.173609
# 2                            15.678607            -106.167117
# 3                             9.369500            -106.221819
# 4                            10.844181            -105.512504
#
#    Hot Spring Latitudes
# 0             38.732602
# 1             38.724037
# 2             38.731589
# 3             38.812768
# 4             37.732996

# %% [markdown]
# MergeMania!!

# %%
#first merge included distance from mountain peak data
# first_dt_mg = pd.merge(cleaned_mountains,charger_mountain_df, on = "Mountain Peak" )
# second_dt_mg = pd.merge(first_dt_mg,gas_mountain_df, on = "Mountain Peak")
# third_dt_mg = pd.merge(second_dt_mg, brewery_mountain_df, on = "Mountain Peak")
# fourth_dt_mg = pd.merge(third_dt_mg, hs_mountain_df, on = "Mountain Peak")
# display(fourth_dt_mg.head())

# %% [markdown]
# We need to group everything by the mountians

# %%
#fire the following DataFrames in Mongo at once, no merge, will display everything 
#(breweries_df, gas_df, charger_df, mountains, co_campsites)
